# %% [markdown]
# # Cómo Aprender Data Science e Inteligencia Artificial

# %% [markdown]
# ## Importancia y Usos de Data Science e Inteligencia Artificial
# ### Oportunidades Laborales en Data Science e Inteligencia Artificial
# ### Glosario Para Entender el Mundo de Data Science e Inteligencia Artidicial
# ### ¿Qué es Data Science?
# Ciencia de datos, es el proceso de descubrir información valiosa de los datos.
# #### ¿Cuál es su finalidad?
# * Tomar decisiones y crear estrategias de negocios
# * Crear productos de software más inteligentes y funcionales.
# #### ¿De qué trata este proceso?
# * Obtención de los datos.
# * Transformar y limpiar datos.
# * Explorar, analizar y visualizar datos.
# * Usar modelos de Machine Learning.
# * Integrar datos e IA a productos de software.
# #### Proceso de la Ciencia de Datos
# * Hacer una pregunta interesante
# * Obtener los datos
# * Explorar los datos
# * Analizar los datos
# * Comunicar y visualizar resultados.## Importancia y Usos de Data Science e Inteligencia Artificial
# ### Oportunidades Laborales en Data Science e Inteligencia Artificial
# ### Glosario Para Entender el Mundo de Data Science e Inteligencia Artidicial
# ### ¿Qué es Data Science?
# Ciencia de datos, es el proceso de descubrir información valiosa de los datos.
# #### ¿Cuál es su finalidad?
# * Tomar decisiones y crear estrategias de negocios
# * Crear productos de software más inteligentes y funcionales.
# #### ¿De qué trata este proceso?
# * Obtención de los datos.
# * Transformar y limpiar datos.
# * Explorar, analizar y visualizar datos.
# * Usar modelos de Machine Learning.
# * Integrar datos e IA a productos de software.
# #### Proceso de la Ciencia de Datos
# * Hacer una pregunta interesante
# * Obtener los datos
# * Explorar los datos
# * Analizar los datos
# * Comunicar y visualizar resultados.
# ### ¿Qué es Inteligencia Artificial? ¿ Cuál es suDiferencia con Data Science?
# * Algoritmos para emular nuestra inteligencia natural.
# * Reconocer patrones en grandes cantidades de datos.
# #### Proceso de Ciencia de Datos: Integrar ML a Producto
# * Ingesta de datos
# * Validación de los datos
# * Preparación de los datos.
# * Entranamiento del modelo.
# * Evaluación del modelo.
# * Validación del modelo.
# * Despliegue del modelo
# * Interfaz del Usuario.
#
# **Data Science** Proceso para analizar datos y generar predicciones para toma de decisiones y crear productos con datos.
# **Inteligencia Artificial** Algoritmos para redecir eventos futuros que emulan cognición.
#
# En el proceso de data science utilizamos inteligencia artificial como una de sus herramientas.
#
# ### ¿Qué es Big Data? ¿ Cuál es su Diferencia con Data Science?
# * Grandes volúmenes de datos muy variados y muy veloces.
# * Resulta complicado procesarlos con métodos tradicionales.
#
# Debe cumplir con las 5v
# **Volumen** El almacenamiento de la masiva cantidad de datos que pueden ser recolectados de múltiples fuentes.
# **Velocidad** Los datos se generan en tiempo real gracias a las interacciones con las fuentes mencionadas, por lo que deben ser procesados con la misma velocidad.
# **Variedad** Todo tipo de datos, ya sea estructurados o no estructurados. podrían ser tablas, textos, imágenes, videos, audio, base de datos.
# **Veracidad** Es la calidad y confiabilidad de los datos.
# **Valor** Los datos deben poder proporcionar un valor o beneficio a la empresa que los está usando.
#
# #### Procesamiento de Big Data
# * Se procesa al dividirla en partes pequeñas en varias máquinas.
# * Tecnologías como Spark, hadoop y servicios de cómputo en la nube.
#
# * Big data es materia prima que podemos usar en data science para hacer análisis más exhaustivos.
# * Incluso podemos utilizar Machine Learning en ese mismo proceso para perfeccionar y evaluar los algoritmos de Inteligencia Artificial que creemos.
#
# ### ¿Qué no es Data Science? ¿Por qué aprenderla?
#
# ### Áreas de Aplicación de Data Science e IA
#
# ### Roles en la Industria: Como funciona los equipos de datos e IA
#
# * Data Scientist
# * Data Analyst
# * Data Engineer
# * Machine Learning Engineer
#
# Recolección, Movimiento/Almacenamiento, Exploración/Transformación, Agregaciones/etiquetado, Aprendizaje/optimización

# %% [markdown]
# ¿Qué areas de conocimiento implica la ciencia de datos?
# Matemáticas y estadisticas, ciencia computacionales, conocimiento de la industria.
#
# ¿Cualquier organización puede empezar a implementar Machine Learning en cualquier momento?
# Falso, antes se necesita haber creado la infraestructura y cultura necesaria siguiendo la jerarquía de necesidades de data science.
#
# ¿Cómo se relacionan Big data e Inteligencia artificial?
# Podemos utilizar Machine Learning con Big data dentro del proceso de data science.
#
# ¿Qué es inteligencia artificial?
# Algoritmos que emulan la inteligencia/cognición natural de seres humanos.
#
# ¿Cuál es una finalidad de data science en organizaciones y empresas?
# Tomar decisiones y crear estrategias de negocios basados en datos.

# %% [markdown]
# ## Data Analyst
#
# ### ¿Qué Hace un Data Analyst?
# * Insights para la toma de decisiones.
# * Extraer datos recolectados.
# * Analizarlos y reportar resultados.
# * Identificar necesidades de información
# * Extraer datos de fuentes. -> con SQL o Python
# * Limpiar y organizar los datos para su análisis.
# * Analizar los datos para identificar patrones y tendencias.
# * Comunicar los hallazgos en tableros o Dashboards.
#
# #### Flujo de trabajo de data analyst
# * Problema o pregunta.
# * Exploración y queries
# * Recopilar información de valor.
# * Crear visualizaciones de la información.
# * Comunicar hallazgos.
#
# #### Roles relacionados
# * Business Analyst
# * Data Visualization Specialist.
#
# ### Herramientas y tecnologías para Data Analysts
# * Consulta de bases de datos con SQL.
# * Software de visualización de datos Power BI y Tableau
# * Excel y Google Sheets.
# * Programación con Python o R
# * Jupyter Notebooks
# * Pandas, Matplotlib, Numpy
# * Probabilidad
# * Estadistica descriptiva.
#
# #### Como empezar?
# * Cómo utilizan los datos las organizaciones con Business Intelligence.
# * Consultar bases de datos con SQL.
# * Herramientas para análisis de datos como Excel, Power BI y Tableau.
# * Estadística aplicada a análisis de datos.
#
# ### La experiencia de un Data Analyst

# %% [markdown]
# ¿Un data analyst debe saber programar?
# No necesariamente, pero te dará una ventaja competitiva.
#
# ¿Cuáles son los software de visualización de datos más utilizados?
# Tableau y Power BI
#
# ¿Cómo se presentan los hallazgos encontrados en los datos?
# Mediante tableros, visualizaciones o reportes

# %% [markdown]
# ## Data Scientist
#
# ### ¿Qué hace un Data Scientist?
# * Obtener, limpiar y procesar datos
# * Diseñar y utilizar modelos de Machine Learning
# * Monitorear la precisión de los datos
# * Automatizar procesos de recolección y transformación de datos.
# * Crear reportes de información en tableros.
# * Incorpora datos a los productos.
#
# #### Data Scientis
# * Incorpora datos a los productos - ingeniería.
# * Programación avanzada POO
# * Machine Learning y estadística avanzada
#
# #### Data Analyst
# * Se enfoca en responder preguntas del negocio.
# * Programación fundamental.
# * Analizar el presente de la organización.
#
# ### Herramientas y tecnologías para Data Scientists
# * Programación con Python o R (Incluyendo POO)
# * Jupyter notebooks
# * Pandas, Numpy, Matplotlib
# * Algoritmos y librerías de machine learning como scikit-learn y TensorFlow.
# * Bases de datos SQL y NoSQL
#
# #### Matemáticas para data scientist
# * Álgebra
# * Estadística descriptiva e inferencial
# * Probabilidad
# * Álgebra lineal
# * Calculo
#
# #### ¿Cómo empezar?
# * Cómo utilizan los datos las organizaciones.
# * Programación con Python y sus librerías para data science.
# * Usar Jupyter Notebooks.
# * Estadística y probabilidad aplicada a data science.
#
# ### La experiencia de un Data Scientist

# %% [markdown]
# ¿Para qué son útiles probabilidad y estadística para un Data Scientist?
# Para analizar y entender datos, descubrir información de valor y patrones ocultos en los datos.
#
# ¿Cuáles son los dos lenguajes de programación más utilizados para Data Scientists?
# Python y R conociendo el paradigma POO
#
# ¿Data Analyst es lo mismo que Data Scientist?
# Falso, una Data Scientist también se enfoca en incorporar datos a productos y utilizar machine learning

# %% [markdown]
# ## Data Engineer
#
# ### ¿Qué hace una Data Engineer?
# * Datos crudos -> Datos limpios para análisis.
# * Trabaja para que el equipo tenga datos para análisis.
# * Crea pipelines ETL
# * Data pipelines de ETL y bases de datos
# * Extraer datos de diferentes fuentes.
# * Transformar los datos para análisis.
# * Bases de datos especializados para análisis.
# * Crear automatizaciones para ETL.
#
# #### Roles relacionados
# * Data Architect
# * Big Data Architect
#
# ### Herramientas y tecnologías para data engineeers
# * Programación con python y bases de ingenieria de Software
# * Linux
# * Automatización y scripting.
# * Jupyter Notebooks y editores de código
# * Manejo avanzado de bases de datos SQL y NoSQL.
# * Pandas, dask y Apache Spark.
# * Airflow.
# * Tecnologías cloud.
# * Contenedores docker.
# * Orquestadores Kubernetes.
# * Estadistística descriptiva
#
# #### ¿Cómo empezar?
# * Python y bases sólidas de ingenieira de software
# * Automatización y scripting.
# * Pandas y Apache Spark.
# * Bases de datos SQL y NoSQL.
#
# ### La experiencia de un Data Engineer

# %% [markdown]
# ¿Cuál es el lenguaje de programación principalmente utilizado por Data Engineers?
# Python
#
# ¿Por qué es importante contar con una Data Engineer en un equipo de Data Science?
# Porque gracias a este rol los equipos de datos pueden tener datos para analizar más fácilmente.
#
# ¿Qué es el proceso ETL?
# Proceso donde se extraen datos, se transforman y se cargan en bases de datos especializadas para analitica

# %% [markdown]
# ## Machine Learning Engineer
#
# ### ¿Qué hace un Machine Learning Engineer?
# * Crear productos basados en IA
# * Escalar modelos de IA
# * Genera una **Evaluación extensiva de métricas** de modelos de machine learning.
# * Construir, escalar y robustecer sistemas de machine learning que **Funcionen en producción**
# * **Colaborar** con data Scientists y otras áreas de ingenieria de software.
# * **Monitoreas el desempeño y funcionalidad** de los sistemas de machine learning.
#
# ### Herramientas y tecnologías para Machine Learning Engineers
# * Programación avanzada con python, Java y C++
# * Bases sólidas de ingenieria de software
# * Jupyter Notebooks.
# * Pandas, Numpy, Matplotlib, seaborn
# * uso extensivo de frameworks y librerias de Machine Learning.
#
# #### Desplegar el modelo
# * Flask o FastAPI
# * Tecnologías Cloud
# * Contenedores Docker
# * Kubernetes
#
# #### Matematicas para machine learning
# * Estadistística descriptiva
# * Probabilidad
# * Álgebra Lineal
# * Cálculo
#
# * Programación con python y bases sólidas de ingenieria de software
# * Uso de librerías para manipulación, análisis y visualización de datos.
# * Matemáticas aplicadas a data science e inteligencia artificial.
# * Aplicación de modelos de machine learning con scikit-learn.
#
# ### La experiencia de un Machine Learning Engineer

# %% [markdown]
# ¿Con qué herramientas podrás desplegar tu modelo?
# Con librerías o contenedores a través de la nube.
#
# ¿Una ML Engineer debe saber de lenguajes de programación de alto y bajo nivel?
# Verdadero, ya que esto le permitirá optimizar el rendimeinto de sus modelos.
#
# ¿En qué parte del flujo de trabajo de la ciencia de datos interviene una ML Engineer?
# Evaluación, validación y despleigue del modelo

# %% [markdown]
# ## Ser Profesional en el Mundo de los Datos e IA
#
# ### Soft skills para data science
#
# ### En sus marcas, listo y fuera
